# %%
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup
from urllib.error import URLError, HTTPError

def trata_html(html):
    return ' '.join(html.split()).replace("> <", "><");

url = 'https://www.olx.com.br/imoveis/aluguel/estado-pb/paraiba/joao-pessoa'
cabecalho = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'}

try:
    request = Request(url, headers = cabecalho)
    response = urlopen(request)
except HTTPError as erro:
    print(erro.status, erro.reason)
except URLError as erro:
    print(erro.reason)
    
html = response.read().decode('utf-8')
html = trata_html(html)

# %%
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())
# Out:
# <html data-reactroot="" lang="pt-BR">
#  <head>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="abuy-list-item-tags-grid_enabled.adv-gemini-less-positions_enabled.cdrelrank-synonym_on.dispute-automatic-decision_A.listing-transactional-badge_enabled.newadcard_enabled.re-attributes-bjQTZ-bjfilters_control.search-custom-filters_enabled.search-intention-filters_control.trackexp-links-azuis_control" name="x-testab-debugger"/>
#   <meta content="#6e0ad6" name="theme-color"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#   <link href="https://olx.com.br/busca?ca=83_s&amp;cg=1002&amp;w=5&amp;zn=4794" media="only screen and (max-width: 640px)" rel="alternate"/>
#   <meta charset="utf-8"/>
#   <meta content="uqJwtiNExrXVCtT-w4AryaEhN-mU4ognZGnDIX3ds-w" name="google-site-verification"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="Oferta de Casas e apartamentos para alugar - João Pessoa, Paraíba. Na OLX você encontra as melhores ofertas perto de você." name="description"/>
#   <meta content="Anúncios Aluguel - casas e apartamentos, Paraíba, DDD 83 - Paraíba, olx" name="keyword"/>
#   <meta content="Compre e venda perto de você | OLX" property="og:title"/>
#   <meta content="OLX" property="og:site_name"/>
#   <meta content="Oferta de Casas e apartamentos para alugar - João Pessoa, Paraíba. Na OLX você encontra as melhores ofertas perto de você." property="og:description"/>
#   <meta content="https://static.bn-static.com/img-49626/olx-share.jpg" property="og:image"/>
#   <meta content="Logo OLX" property="og:image:alt"/>
#   <meta content="website" property="og:type"/>
#   <meta content="pt_BR" property="og:locale"/>
#   <meta content="https://www.olx.com.br/imoveis/aluguel/estado-pb/paraiba/joao-pessoa" property="og:url"/>
#   <meta content="106401512762894" property="fb:app_id"/>
#   <meta content="Compre e venda perto de você | OLX" name="twitter:title"/>
#   <meta content="Oferta de Casas e apartamentos para alugar - João Pessoa, Paraíba. Na OLX você encontra as melhores ofertas perto de você." name="twitter:description"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@OLX_Brasil" name="twitter:site"/>
#   <meta content="@OLX_Brasil" name="twitter:creator"/>
#   <meta content="https://static.bn-static.com/img-49626/olx-share.jpg" name="twitter:image"/>
#   <meta content="OLX" name="twitter:app:name:iphone"/>
#   <meta content="692808319" name="twitter:app:id:iphone"/>
#   <meta content="https://www.olx.com.br/imoveis/aluguel/estado-pb/paraiba/joao-pessoa" name="twitter:url"/>
#   <meta content="olxapp://list/&amp;category=1002&amp;state=13&amp;region=83" name="twitter:app:url:iphone"/>
#   <meta content="OLX" name="twitter:app:name:ipad"/>
#   <meta content="692808319" name="twitter:app:id:ipad"/>
#   <meta content="olxapp://list/&amp;category=1002&amp;state=13&amp;region=83" name="twitter:app:url:ipad"/>
#   <meta content="692808319" property="al:ios:app_store_id"/>
#   <meta content="OLX" property="al:ios:app_name"/>
#   <meta content="olxapp://list/&amp;category=1002&amp;state=13&amp;region=83" property="al:ios:url"/>
#   <link href="olxapp://list/?source=organic&amp;category=1002&amp;state=13&amp;region=83" rel="alternate"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="OLX" name="author"/>
#   <meta content="OLX" name="application-name"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="OLX Brasil" name="apple-mobile-web-app-title"/>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"WebSite","url":"https://wwww.olx.com.br","name":"OLX","alternateName":"OLX"}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org/","@type":"Organization","name":"OLX","alternateName":"OLX","url":"https://wwww.olx.com.br","logo":"https://www.olx.com.br/mapa-do-site/static/media/brand-olx.d04ffe18.svg","sameAs":["https://www.facebook.com/olxbrasil","https://twitter.com/olx_Brasil","https://plus.google.com/+olxbrasil","https://www.instagram.com/olxbrasil/","https://www.youtube.com/user/OLXBrasil"]}
#   </script>
#   <script>
#    !function(t,e,n,s,a,c,i,o,p){t.AppsFlyerSdkObject=a,t.AF=t.AF||function(){ (t.AF.q=t.AF.q||[]).push([Date.now()].concat(Array.prototype.slice.call(arguments)))}, t.AF.id=t.AF.id||i,t.AF.plugins={},o=e.createElement(n),p=e.getElementsByTagName(n)[0],o.async=1, o.src="https://websdk.appsflyer.com?"+(c.length>0?"st="+c.split(",").sort().join(",")+"&":"")+(i.length>0?"af_id="+i:""), p.parentNode.insertBefore(o,p)}(window,document,"script",0,"AF","banners",{banners: {key: "98255dc8-e69c-4578-9394-e2bfcf7e4cf7"}}); // Smart Banners are by default set to the max z-index value, so they won't be hidden by the // website elements. // Isso pode ser alterado se você quiser que alguns componentes do site estejam no topo do banner. AF('banners', 'showBanner', { bannerZIndex: 1000, additionalParams: { p1: "v1", p2: "v2"}});
#   </script>
#   <link href="https://static.olx.com.br/cd/vi/images/icons/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="https://static.olx.com.br/cd/vi/images/icons/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="https://static.olx.com.br/cd/vi/images/icons/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="https://static.olx.com.br/cd/vi/images/icons/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="https://static.olx.com.br/cd/vi/images/icons/site.webmanifest" rel="manifest"/>
#   <link color="#6e0ad6" href="https://static.olx.com.br/cd/vi/images/icons/safari-pinned-tab.svg" rel="mask-icon"/>
#   <script>
#    window.dataLayer = [{"pageType":"listing","page":{"pageType":"listing","detail":{"region_id":83,"state_id":13,"apply_filter":false,"listing":"new","parent_category_id":"1000","category_id":"1002","filters":{"region":83,"state":13,"zone":4794,"selectedCategoryCode":"1002","sorting":"relevance","selectedAdTypes":["1","0"],"pageIndex":1},"totalOfAds":3047,"length":50,"lastInternalSource":null}},"site":{"isMobile":false,"source":"web"}}]
#   </script>
#   <script>
#    function buildPerformanceDatalayer(){var e=window.dataLayer[0];e.page.detail.memoryStatus={},window&&window.navigator&&(e.page.detail.cpuCores=window.navigator.hardwareConcurrency,window.navigator.connection&&(e.page.detail.connectionType=window.navigator.connection.effectiveType,e.page.detail.downloadLink=window.navigator.connection.downlink,e.page.detail.saveData=window.navigator.connection.saveData),window.navigator.deviceMemory&&(e.page.detail.memoryStatus.deviceMemory=window.navigator.deviceMemory)),window&&window.performance&&window.performance.memory&&(e.page.detail.memoryStatus.totalJSHeapSize=window.performance.memory.totalJSHeapSize,e.page.detail.memoryStatus.usedJSHeapSize=window.performance.memory.usedJSHeapSize,e.page.detail.memoryStatus.jsHeapSizeLimit=window.performance.memory.jsHeapSizeLimit)}buildPerformanceDatalayer();
#   </script>
#   <link href="https://www.olx.com.br/imoveis/aluguel/estado-pb/paraiba/joao-pessoa" rel="canonical"/>
#   <link as="style" href="https://static.olx.com.br/design-system/olx-reset.min.css" rel="preload"/>
#   <link href="https://static.olx.com.br/design-system/olx-reset.min.css" media="screen" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com" rel="preconnect"/>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://fonts.googleapis.com/css2?family=Nunito+Sans:wght@300;400;600;700&amp;display=swap" media="screen" rel="stylesheet"/>
#   <link as="style" href="https://static.olx.com.br/design-system/ds-tokens.css" rel="preload"/>
#   <link href="https://static.olx.com.br/design-system/ds-tokens.css" media="screen" rel="stylesheet"/>
#   <script>
#    window.dfpPageSegmentationDataLayer = [{"plataforma":"desktop","ABTest":["abuy-list-item-tags-grid_enabled","adv-gemini-less-positions_enabled","cdrelrank-synonym_on","dispute-automatic-decision_A","listing-transactional-badge_enabled","newadcard_enabled","re-attributes-bjQTZ-bjfilters_control","search-custom-filters_enabled","search-intention-filters_control","trackexp-links-azuis_control"],"uf":"PB","ddd":83,"search_kw":"","bairro":[""],"zona":"joao-pessoa-83","searchCategoryLevelZero":"1000","selectedPayShip":null}]
#   </script>
#   <script async="" src="https://www.googletagservices.com/tag/js/gpt.js" type="text/javascript">
#   </script>
#   <script>
#    window.googletag = window.googletag || {cmd: []};
#   </script>
#   <script async="" src="//micro.rubiconproject.com/prebid/dynamic/14702.js?DM_env=web" type="text/javascript">
#   </script>
#   <script>
#    var pbjs = pbjs || {}; pbjs.que = pbjs.que || [];
#   </script>
#   <meta pubid="bc9a0bab-ec1b-4e7d-b551-4ae0e344407b"/>
#   <script defer="" src="https://pub.olx.com.br/detect-adblocker.js">
#   </script>
#   <script defer="" src="https://pub.olx.com.br/listing.js">
#   </script>
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-546N2JV" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0], j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src= 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f); })(window,document,'script','dataLayer','GTM-546N2JV');
#   </script>
#   <script defer="" type="text/javascript">
#    (function(){var g=function(e,h,f,g){ this.get=function(a){for(var a=a+"=",c=document.cookie.split(";"),b=0,e=c.length;b<e;b++){for(var d=c[b];" "==d.charAt(0);)d=d.substring(1,d.length);if(0==d.indexOf(a))return d.substring(a.length,d.length)}return null}; this.set=function(a,c){var b="",b=new Date;b.setTime(b.getTime()+6048E5);b="; expires="+b.toGMTString();document.cookie=a+"="+c+b+"; path=/; "}; this.check=function(){var a=this.get(f);if(a)a=a.split(":");else if(100!=e)"v"==h&&(e=Math.random()>=e/100?0:100),a=[h,e,0],this.set(f,a.join(":"));else return!0;var c=a[1];if(100==c)return!0;switch(a[0]){case "v":return!1;case "r":return c=a[2]%Math.floor(100/c),a[2]++,this.set(f,a.join(":")),!c}return!0}; this.go=function(){if(this.check()){var a=document.createElement("script");a.type="text/javascript";a.src=g;document.body&&document.body.appendChild(a)}}; this.start=function(){var t=this;"complete"!==document.readyState?window.addEventListener?window.addEventListener("load",function(){t.go()},!1):window.attachEvent&&window.attachEvent("onload",function(){t.go()}):t.go()};}; try{(new g(100,"r","QSI_S_ZN_4JiGC94Y6w5woVo","https://zn4jigc94y6w5wovo-olxbr.siteintercept.qualtrics.com/SIE/?Q_ZID=ZN_4JiGC94Y6w5woVo")).start()}catch(i){}})();
#   </script>
#   <div id="ZN_4JiGC94Y6w5woVo">
#   </div>
#   <title>
#    Casas e apartamentos para alugar - João Pessoa, Paraíba | OLX
#   </title>
#   <style data-styled="UfgLP kUhqjE jUPCvE iLWqoT cBVFrn hzUJDA gKTKbz PQeMv fetGj kilIMj hmbczW fxROPQ kJxrcE gEqtSq kNEdyZ bkoSfF dQYDAH kMhCAe HAqQo ehQTxA iZFtlv ipGNYR dKYktT iLhBzq cgVvMg bYIRtK hOAElr fAprjt djByBH cpraWt hbxMuc cxGeqJ ijUxGh iThXCX CBzGE iMTFtg bGQyPd ldQwSR dSLMkb KJfcY sIgOl eNmqhV cSgRaW bDXZLe bVgqOb iYoIcd bbFokt cQPuAI esODqn ioAVKB eWNSWv gWxTLm gPukpx hSiWqw irpDAC kbHpBK hbByQ HAmtJ bKUeFO xycMU NDYz dLqWjV dhyYGc lfTqxY bJaYRj ihwZkk ebdYDV cXqIMF jQIyGw jrbFUN dkdVuH eWSASP kAjtPt bhIzcq eFFEHx jViSDP bVUFRk jDDMIC glcShM iOyFmS lgjPoE cIlbXx fdOMeZ cEubYc ghBVzA fAopn iUMNkO bRQryy fiwAfL dHKDuC hGsITu lewNeb bytyxL cbbXMA iMTZxE esYoDB kqkkpF kbFAIO gIduSn jYSzON gMZkKD dxjIPp lSiAl hDVagN cCUzsG jzxycu iforLC kaZaqn dSrKbb gvtffP cBfPri bcHDBL RqJFM flnVLq clhToU lfgRpk kgAecM hPByVK gVpDQp dSDWwE bsmtJb cKAgSN jeUoCm cPjFhj leIzac kMUQGx kPPHLA jmrnXd jEqkks jVsRdB cEjcKV cdUZWU hZoNBa jCsVDH kNxYoj ifBjVY jysNaO ggnAkg hoxDFa jGNIcq hQdPhM gmZcKb iavLIw gxCyeW hbaDeW icIbIZ bzhQcE ijPVok fMxuyb otEye dKzxhF iXNsOs jlUddD fAdSuy bAczwh kXyLfh hLEfnK bXpyef cDekXo kuaeHC iOeZCc haHGkl glNpPt gfnRDI jVWeXe idKind YLxqn kOELsI gfdgOF iUhGrT jOmlaS dGiePB eFbHOl euDYwT iBEEqP lpdTDu jWGzQI fJFlVQ kRrmfb iOmLQY iORgqK jQSKCw loNQmp jMAFZV hoDStb hBnEsX kRemsz gTTLGp gpDieb jTKpIo HmLpm dbHtNe cxdaxN fkUvtT vnAVT gUNRNy gtHJlm PVeri bJEtCW ePVnzl cCRSCs bKQYjj gDRgAg iMhkJx ggdEQC ZnaEv LRiLa bBIzJj dQbOE dkYTfj csYflq lnwdXC fHjths glYQgW gBjQsq hdROIa hAONqD bdQAUC cVOrsu icHTrE kfvkxn jCXdMi kTTIUb ivsVmy ljcOqr bLyHmy hsDyXo fmXvNx fyxOZX guRQTM hhsrmS cLIcla kNxznw hwCOAd jNFXKK dtyzck gwxTMN cToWxR iurLoA hZohCV fExIAI bFBoqe cuKKgI zcTDu HutRS kntIvV eNBJyg dvcyfD jNGRBA jdIDkd bjnzhV huFwya gSNULD khoztA gjneWt cIJNya kyhiUC pWUxf bbhdCb bzUofP hHqPTj fKOLao kiBSyL fqDYpJ dWYMAi gZuhWp kDVQFY eFXRHn bXnrWQ ikBDtl dGMPPn eJCbzj dFEFoQ iHjvua dtzqvr ejffAZ kwiJGa XZIpN jEDFNq hCpFrO kUlcon bwaDdh bqeUUL bIIYRs cdYFBp cqRwPy VMylX btCOoe jGYopB jBDlzO gBteZx rRQgw lfQETj cLQXSQ javKJU doofcG epYOXH RAyVy eHIWLE kdWmac kPsGhS QtOQI hUHECR hEtrnt hWozpX jqQzXH hJFxIZ eSaedu eBRaXH gWzezu iFiTng hKgzPE kTlapW hRpdMS htIWfJ kJfBmj hsTaDz guEgWY uvMTU tJeDp eIlfkI dNIuWs bEJUad dpPMei ioyevC hSmLZl bcgvPM bVGAKc fzsCno cxrWpf dGGutS idxXvv hubnRA hmujPh gMnSWp dSQrRq fnhGpe kltrKt bSLYYS dKlIQA gQzDHR juQWKY iVuCdu dMZaaN cPZDhK kbQaOE hDlSQQ kGEDfm IdcTo latyHw IPiTs bemaKi iaTarT spIVL vmlSz laehpd kuaQIx jEUizm hFIAtY iEcqJU eQQwGB RBPWE jeEGQv cnzuRZ todbs dzAaoj YfujD ffrqTM dGZNGV kskGsm kFMkhX bmkBsT keadiS Lvdkq gjszjU fZoIzL heHxXT sLVHz jlnrgV dUnJVd gHCsfm kJrkKt jZOcvC imkUct efbmpH ecSOri fywKGl kbWREw bWTAjG evYBhx lgwjMd fnzuhx iWnXwx jixGLj gtMYZy jwVEyp efdjaS eBNbGG gvUjvU AUmhe dyqzOq gHLEZy eWWRAX eWoggW fcSBCx kSHqfB cllrgO effUCd eKXhEQ dhRfTv htvnvL dWtMUn gPZcyB cmOmwy dQjJRh bFIsKI eIvdxS dfJNkV clMRaN cassMN kcKPUk dEjXeK ifavhK JwzRF pRgjx" data-styled-version="4.2.0">
#    /* sc-component-id: h3us20-2 */ .bdQAUC{display:none;} @media (min-width:52.5em){.bdQAUC{display:block;}} /* sc-component-id: h3us20-3 */ .csYflq{display:block;} @media (min-width:52.5em){.csYflq{display:none;}} /* sc-component-id: h3us20-4 */ @media (min-width:52.5em){.cxGeqJ{display:none;}}@media (min-width:1em) and (max-width:52.4375em){.ijUxGh{display:none;}}@media (min-width:52.5em){.cxGeqJ{display:none;}}@media (min-width:1em) and (max-width:52.4375em){.ijUxGh{display:none;}} /* sc-component-id: h3us20-5 */ .jeUoCm{width:100%;} @media (min-width:1em){.jeUoCm{height:px;width:px;}} @media (min-width:37.5em){.jeUoCm{height:px;width:px;}} @media (min-width:45em){.jeUoCm{height:px;width:px;}} @media (min-width:52.5em){.jeUoCm{height:16px;width:16px;}} @media (min-width:71.19em){.jeUoCm{height:px;width:px;}} @media (min-width:78.69em){.jeUoCm{height:px;width:px;}} @media (min-width:79.5em){.jeUoCm{height:px;width:px;}}.cPjFhj{width:100%;} @media (min-width:1em){.cPjFhj{height:px;width:px;}} @media (min-width:37.5em){.cPjFhj{height:px;width:px;}} @media (min-width:45em){.cPjFhj{height:px;width:px;}} @media (min-width:52.5em){.cPjFhj{height:24px;width:24px;}} @media (min-width:71.19em){.cPjFhj{height:px;width:px;}} @media (min-width:78.69em){.cPjFhj{height:px;width:px;}} @media (min-width:79.5em){.cPjFhj{height:px;width:px;}}.leIzac{width:100%;} @media (min-width:1em){.leIzac{height:16px;width:16px;}} @media (min-width:37.5em){.leIzac{height:px;width:px;}} @media (min-width:45em){.leIzac{height:px;width:px;}} @media (min-width:52.5em){.leIzac{height:16px;width:16px;}} @media (min-width:71.19em){.leIzac{height:px;width:px;}} @media (min-width:78.69em){.leIzac{height:px;width:px;}} @media (min-width:79.5em){.leIzac{height:px;width:px;}}.leIzac{width:100%;} @media (min-width:1em){.leIzac{height:16px;width:16px;}} @media (min-width:37.5em){.leIzac{height:px;width:px;}} @media (min-width:45em){.leIzac{height:px;width:px;}} @media (min-width:52.5em){.leIzac{height:16px;width:16px;}} @media (min-width:71.19em){.leIzac{height:px;width:px;}} @media (min-width:78.69em){.leIzac{height:px;width:px;}} @media (min-width:79.5em){.leIzac{height:px;width:px;}}.kMUQGx{width:100%;} @media (min-width:1em){.kMUQGx{height:16px;width:16px;}} @media (min-width:37.5em){.kMUQGx{height:px;width:px;}} @media (min-width:45em){.kMUQGx{height:px;width:px;}} @media (min-width:52.5em){.kMUQGx{height:24px;width:24px;}} @media (min-width:71.19em){.kMUQGx{height:px;width:px;}} @media (min-width:78.69em){.kMUQGx{height:px;width:px;}} @media (min-width:79.5em){.kMUQGx{height:px;width:px;}}.kPPHLA{width:100%;} @media (min-width:1em){.kPPHLA{height:24px;width:24px;}} @media (min-width:37.5em){.kPPHLA{height:px;width:px;}} @media (min-width:45em){.kPPHLA{height:px;width:px;}} @media (min-width:52.5em){.kPPHLA{height:8px;width:8px;}} @media (min-width:71.19em){.kPPHLA{height:px;width:px;}} @media (min-width:78.69em){.kPPHLA{height:px;width:px;}} @media (min-width:79.5em){.kPPHLA{height:px;width:px;}}.jmrnXd{width:100%;} @media (min-width:1em){.jmrnXd{height:24px;width:24px;}} @media (min-width:37.5em){.jmrnXd{height:px;width:px;}} @media (min-width:45em){.jmrnXd{height:px;width:px;}} @media (min-width:52.5em){.jmrnXd{height:24px;width:24px;}} @media (min-width:71.19em){.jmrnXd{height:px;width:px;}} @media (min-width:78.69em){.jmrnXd{height:px;width:px;}} @media (min-width:79.5em){.jmrnXd{height:px;width:px;}}.jEqkks{width:100%;} @media (min-width:1em){.jEqkks{height:24px;width:24px;}} @media (min-width:37.5em){.jEqkks{height:px;width:px;}} @media (min-width:45em){.jEqkks{height:px;width:px;}} @media (min-width:52.5em){.jEqkks{height:32px;width:32px;}} @media (min-width:71.19em){.jEqkks{height:px;width:px;}} @media (min-width:78.69em){.jEqkks{height:px;width:px;}} @media (min-width:79.5em){.jEqkks{height:px;width:px;}}.jVsRdB{width:100%;} @media (min-width:1em){.jVsRdB{height:32px;width:32px;}} @media (min-width:37.5em){.jVsRdB{height:px;width:px;}} @media (min-width: ...
#   </style>
#   <style data-styled="kEcvhw dKXXsZ CBCnm" data-styled-version="4.2.0">
#    /* sc-component-id: sc-keyframes-kEcvhw */ @-webkit-keyframes kEcvhw{0%{top:0;}100%{top:-250px;}} @keyframes kEcvhw{0%{top:0;}100%{top:-250px;}} /* sc-component-id: wodqy3-3 */ .dKXXsZ{list-style-type:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:var(--spacing-inset-xs);font-size:12px;color:var(--color-neutral-darker);} /* sc-component-id: sc-1lwbm0p-0 */ .CBCnm{padding:4px 8px;background-color:#ddd;border-radius:4px;width:140px;}
#   </style>
#   <style data-styled="CBzGE iMTFtg bGQyPd ldQwSR dSLMkb KJfcY sIgOl cSgRaW bDXZLe bVgqOb iYoIcd bbFokt cQPuAI esODqn ioAVKB eWNSWv gWxTLm gPukpx hSiWqw irpDAC kbHpBK hbByQ HAmtJ bKUeFO xycMU NDYz dLqWjV dhyYGc lfTqxY bJaYRj ebdYDV cXqIMF jrbFUN dkdVuH eWSASP kAjtPt bhIzcq eFFEHx jViSDP bVUFRk jDDMIC glcShM iOyFmS lgjPoE cIlbXx fdOMeZ cEubYc ghBVzA fAopn iUMNkO bRQryy fiwAfL iMTZxE esYoDB kqkkpF kbFAIO gIduSn kgAecM hPByVK gVpDQp dSDWwE kEcvhw bsmtJb cKAgSN jeUoCm cPjFhj leIzac kMUQGx kPPHLA jmrnXd jEqkks jVsRdB cEjcKV cdUZWU hZoNBa hoxDFa jGNIcq hQdPhM gmZcKb iavLIw gxCyeW hbaDeW icIbIZ bzhQcE ijPVok fMxuyb otEye dKzxhF iXNsOs jlUddD fAdSuy bAczwh kXyLfh hLEfnK bXpyef cDekXo kuaeHC iOeZCc haHGkl glNpPt gfnRDI jVWeXe idKind YLxqn kOELsI gfdgOF iUhGrT jOmlaS dGiePB jMAFZV loNQmp hoDStb hBnEsX kRemsz gTTLGp gpDieb jTKpIo dQbOE dkYTfj cBVFrn fetGj kilIMj hmbczW fxROPQ kJxrcE gEqtSq kNEdyZ bkoSfF dQYDAH kMhCAe HAqQo ehQTxA iZFtlv ipGNYR dKYktT iLhBzq iLWqoT cgVvMg iThXCX cxGeqJ ijUxGh csYflq lnwdXC fHjths glYQgW gBjQsq hdROIa bdQAUC cVOrsu icHTrE kfvkxn jCXdMi kTTIUb ivsVmy ljcOqr bLyHmy hsDyXo fmXvNx fyxOZX guRQTM hhsrmS cLIcla kNxznw hwCOAd jNFXKK dtyzck cToWxR iurLoA hZohCV fExIAI cuKKgI HutRS kntIvV eNBJyg dvcyfD jNGRBA jdIDkd bjnzhV huFwya gSNULD khoztA gjneWt cIJNya kyhiUC pWUxf bbhdCb bzUofP hHqPTj fKOLao kiBSyL fqDYpJ dWYMAi gZuhWp kDVQFY eFXRHn bXnrWQ ikBDtl dGMPPn eJCbzj dFEFoQ iHjvua dtzqvr ejffAZ kwiJGa XZIpN jEDFNq hCpFrO kUlcon bwaDdh bqeUUL bIIYRs cdYFBp cqRwPy VMylX btCOoe jGYopB jBDlzO gBteZx rRQgw lfQETj cLQXSQ javKJU doofcG epYOXH RAyVy eHIWLE kdWmac kPsGhS QtOQI hUHECR hEtrnt hWozpX jqQzXH hJFxIZ eSaedu eBRaXH gWzezu iFiTng hKgzPE kTlapW hRpdMS htIWfJ kJfBmj hsTaDz dKXXsZ guEgWY uvMTU tJeDp eIlfkI dNIuWs bEJUad dpPMei ioyevC hSmLZl bcgvPM bVGAKc fzsCno cxrWpf dGGutS idxXvv jwVEyp efdjaS eBNbGG gvUjvU jHIbuy bUqYYC cejjLe gFWhPM gcsPxd dPfgQT jXtYrP gaZanT iZKQUv jHNeOF fVjAtK eheJey dZiziw jKyfMb eUSYUc bEdHbS hJQkIP gAcTLg NTTCv hpeKug jWoujM hbmDFy kzoUDY crTDDD jOyibB PtRtj kbiRpN ktmlpG iYkBSS gcOAdt jWZays fzUiFp cPBiLE jbAySn fPzGRi jnIIto gXTVFc jtzdyi fzHZAM fNKKOH kZDyAU bVwkKy jhmNBD" data-styled-version="4.2.0">
#    /* sc-component-id: h3us20-2 */ .bdQAUC{display:none;} @media (min-width:52.5em){.bdQAUC{display:block;}} /* sc-component-id: h3us20-3 */ .csYflq{display:block;} @media (min-width:52.5em){.csYflq{display:none;}} /* sc-component-id: h3us20-4 */ @media (min-width:52.5em){.cxGeqJ{display:none;}}@media (min-width:1em) and (max-width:52.4375em){.ijUxGh{display:none;}} /* sc-component-id: h3us20-5 */ .jeUoCm{width:100%;} @media (min-width:1em){.jeUoCm{height:px;width:px;}} @media (min-width:37.5em){.jeUoCm{height:px;width:px;}} @media (min-width:45em){.jeUoCm{height:px;width:px;}} @media (min-width:52.5em){.jeUoCm{height:16px;width:16px;}} @media (min-width:71.19em){.jeUoCm{height:px;width:px;}} @media (min-width:78.69em){.jeUoCm{height:px;width:px;}} @media (min-width:79.5em){.jeUoCm{height:px;width:px;}}.cPjFhj{width:100%;} @media (min-width:1em){.cPjFhj{height:px;width:px;}} @media (min-width:37.5em){.cPjFhj{height:px;width:px;}} @media (min-width:45em){.cPjFhj{height:px;width:px;}} @media (min-width:52.5em){.cPjFhj{height:24px;width:24px;}} @media (min-width:71.19em){.cPjFhj{height:px;width:px;}} @media (min-width:78.69em){.cPjFhj{height:px;width:px;}} @media (min-width:79.5em){.cPjFhj{height:px;width:px;}}.leIzac{width:100%;} @media (min-width:1em){.leIzac{height:16px;width:16px;}} @media (min-width:37.5em){.leIzac{height:px;width:px;}} @media (min-width:45em){.leIzac{height:px;width:px;}} @media (min-width:52.5em){.leIzac{height:16px;width:16px;}} @media (min-width:71.19em){.leIzac{height:px;width:px;}} @media (min-width:78.69em){.leIzac{height:px;width:px;}} @media (min-width:79.5em){.leIzac{height:px;width:px;}}.kMUQGx{width:100%;} @media (min-width:1em){.kMUQGx{height:16px;width:16px;}} @media (min-width:37.5em){.kMUQGx{height:px;width:px;}} @media (min-width:45em){.kMUQGx{height:px;width:px;}} @media (min-width:52.5em){.kMUQGx{height:24px;width:24px;}} @media (min-width:71.19em){.kMUQGx{height:px;width:px;}} @media (min-width:78.69em){.kMUQGx{height:px;width:px;}} @media (min-width:79.5em){.kMUQGx{height:px;width:px;}}.kPPHLA{width:100%;} @media (min-width:1em){.kPPHLA{height:24px;width:24px;}} @media (min-width:37.5em){.kPPHLA{height:px;width:px;}} @media (min-width:45em){.kPPHLA{height:px;width:px;}} @media (min-width:52.5em){.kPPHLA{height:8px;width:8px;}} @media (min-width:71.19em){.kPPHLA{height:px;width:px;}} @media (min-width:78.69em){.kPPHLA{height:px;width:px;}} @media (min-width:79.5em){.kPPHLA{height:px;width:px;}}.jmrnXd{width:100%;} @media (min-width:1em){.jmrnXd{height:24px;width:24px;}} @media (min-width:37.5em){.jmrnXd{height:px;width:px;}} @media (min-width:45em){.jmrnXd{height:px;width:px;}} @media (min-width:52.5em){.jmrnXd{height:24px;width:24px;}} @media (min-width:71.19em){.jmrnXd{height:px;width:px;}} @media (min-width:78.69em){.jmrnXd{height:px;width:px;}} @media (min-width:79.5em){.jmrnXd{height:px;width:px;}}.jEqkks{width:100%;} @media (min-width:1em){.jEqkks{height:24px;width:24px;}} @media (min-width:37.5em){.jEqkks{height:px;width:px;}} @media (min-width:45em){.jEqkks{height:px;width:px;}} @media (min-width:52.5em){.jEqkks{height:32px;width:32px;}} @media (min-width:71.19em){.jEqkks{height:px;width:px;}} @media (min-width:78.69em){.jEqkks{height:px;width:px;}} @media (min-width:79.5em){.jEqkks{height:px;width:px;}}.jVsRdB{width:100%;} @media (min-width:1em){.jVsRdB{height:32px;width:32px;}} @media (min-width:37.5em){.jVsRdB{height:px;width:px;}} @media (min-width:45em){.jVsRdB{height:px;width:px;}} @media (min-width:52.5em){.jVsRdB{height:24px;width:24px;}} @media (min-width:71.19em){.jVsRdB{height:px;width:px;}} @media (min-width:78.69em){.jVsRdB{height:px;width:px;}} @media (min-width:79.5em){.jVsRdB{height:px;width:px;}}.cEjcKV{width:100%;} @media (min-width:1em){.cEjcKV{height:16px;width:16px;}} @media (min-width:37.5em){.cEjcKV{height:px;width:px;}} @media (min-width:45em){.cEjcKV{height:px;width:px;}} @media (min-width:52.5em){.cEjcKV{height:px;width:px;}} @media (min-width:71.19em){.c ...
#   </style>
#   <script data-json='{"listingProps":{"olxPayEligibile":false,"filters":{"region":83,"state":13,"zone":4794,"selectedCategoryCode":"1002","sorting":"relevance","selectedAdTypes":["1","0"],"pageIndex":1},"searchBoxProps":{"mode":"leafCategory","selectedCategory":{"value":"1002","breadcrumb_name":"Aluguel","leaf":"1","level":"1","min_location":"sd_id","name":"Aluguel - casas e apartamentos","parent":"1000","friendlyName":"imoveis/aluguel"},"searchLinks":[{"label":"Todas as categorias","url":"https://www.olx.com.br/estado-pb/paraiba/joao-pessoa"},{"label":"Imóveis","url":"https://www.olx.com.br/imoveis/estado-pb/paraiba/joao-pessoa"}],"filtersUI":[{"categoryUI":{"filterUI":1009,"category":"1002","order":0,"platform":"web"},"filterUI":{"id":1009,"type":"checkbox","filterName":"realestatetype_1002","data":{"label":"Tipo"}},"filterValues":[{"value_qs":"1020","value":"1020","label":"Apartamentos para alugar","url":"https://www.olx.com.br/imoveis/aluguel/apartamentos/estado-pb/paraiba/joao-pessoa"},{"value_qs":"1040","value":"1040","label":"Casas para alugar","url":"https://www.olx.com.br/imoveis/aluguel/casas/estado-pb/paraiba/joao-pessoa"},{"value_qs":"1060","value":"1060","label":"Quartos para alugar","url":"https://www.olx.com.br/imoveis/aluguel/aluguel-de-quartos/estado-pb/paraiba/joao-pessoa"}]},{"categoryUI":{"filterUI":5,"category":"1002","order":4,"platform":"web"},"filterUI":{"id":5,"type":"integer_range","filterName":"price_text","data":{"label":"Preço","placeholder":{"min":"Min.","max":"Máx."}}}},{"categoryUI":{"filterUI":12308,"category":"1002","order":5,"platform":"web"},"filterUI":{"id":12308,"type":"integer_range","filterName":"iptu","data":{"label":"IPTU","placeholder":{"min":"Min.","max":"Máx."}}}},{"categoryUI":{"filterUI":12306,"category":"1002","order":6,"platform":"web"},"filterUI":{"id":12306,"type":"integer_range","filterName":"condominio","data":{"label":"Condomínio","placeholder":{"min":"Min.","max":"Máx."}}}},{"categoryUI":{"filterUI":1010,"category":"1002","order":7,"platform":"web"},"filterUI":{"id":1010,"type":"selection_range","filterName":"size_0","data":{"label":"Área","placeholder":{"min":"Min.","max":"Máx."}}},"filterValues":[{"value_qs":"0","value":"0","label":"0"},{"value_qs":"1","value":"30","label":"30"},{"value_qs":"2","value":"60","label":"60"},{"value_qs":"3","value":"90","label":"90"},{"value_qs":"4","value":"120","label":"120"},{"value_qs":"5","value":"150","label":"150"},{"value_qs":"6","value":"180","label":"180"},{"value_qs":"7","value":"200","label":"200"},{"value_qs":"8","value":"250","label":"250"},{"value_qs":"9","value":"300","label":"300"},{"value_qs":"10","value":"400","label":"400"},{"value_qs":"11","value":"500","label":"500"},{"value_qs":"12","value":"","label":"Acima de 500","isOpenInterval":true}]},{"categoryUI":{"filterUI":1011,"category":"1002","order":8,"platform":"web"},"filterUI":{"id":1011,"type":"selection_range","filterName":"rooms","data":{"label":"Número de quartos","placeholder":{"min":"Min.","max":"Máx."}}},"filterValues":[{"value_qs":"0","value":"0","label":"0"},{"value_qs":"1","value":"1","label":"1"},{"value_qs":"2","value":"2","label":"2"},{"value_qs":"3","value":"3","label":"3"},{"value_qs":"4","value":"4","label":"4"},{"value_qs":"5","value":"5","label":"5+"}]},{"categoryUI":{"filterUI":1012,"category":"1002","order":9,"platform":"web"},"filterUI":{"id":1012,"type":"selection_range","filterName":"bathrooms","data":{"label":"Número de banheiros","placeholder":{"min":"Min.","max":"Máx."}}},"filterValues":[{"value_qs":"0","value":"0","label":"0"},{"value_qs":"1","value":"1","label":"1"},{"value_qs":"2","value":"2","label":"2"},{"value_qs":"3","value":"3","label":"3"},{"value_qs":"4","value":"4","label":"4"},{"value_qs":"5","value":"5","label":"5+"}]},{"categoryUI":{"filterUI":1013,"category":"1002","order":10,"platform":"web"},"filterUI":{"id":1013,"type":"selection","filterName":"garage_spaces","data":{"label":"Vagas na garagem","placeholder":"Escolher"}},"filt ...
#   </script>
#   <style>
#    body{ margin:0; text-rendering: geometricPrecision; font-family: "Nunito Sans", Arial, Helvetica; } .hKFFlZ { margin-left: 10px; margin-right: 10px; margin-bottom: 15px; margin-top: 15px; }
#   </style>
#  </head>
#  <body>
#   <div id="root">
#    <div id="header-container">
#     <div id="listing">
#      <div class="h3us20-6 UfgLP">
#       <div class="h3us20-4 cxGeqJ" from="lg">
#        <div>
#         <header class="show-search-input sc-cZBZkQ CBzGE" data-ds-component="DS-Header" id="header">
#          <nav aria-label="Menu principal" class="sc-ecaExY iMTFtg">
#           <div class="sc-gbzWSY bGQyPd">
#            <div class="sc-jqIZGH ldQwSR">
#             <div class="sc-kcDeIU dSLMkb">
#              <a class="skip-link ds-primary-link sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="#header">
#               Ir para o menu principal
#              </a>
#              <a class="skip-link ds-primary-link sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="#main">
#               Ir para o conteúdo da página
#              </a>
#              <a class="skip-link ds-primary-link sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="#footer">
#               Ir para o rodapé
#              </a>
#             </div>
#             <button aria-controls="ds-overflow-menu" aria-expanded="false" class="header-mobile-button ds-primary-link sc-BngTV cSgRaW" data-ds-component="DS-Button">
#              <span aria-hidden="true" class="sc-iCwjlJ bDXZLe">
#               <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                <path d="M3 12.75a.75.75 0 110-1.5h18a.75.75 0 110 1.5H3zm0-6a.75.75 0 010-1.5h18a.75.75 0 110 1.5H3zm0 12a.75.75 0 110-1.5h18a.75.75 0 110 1.5H3z" fill="currentColor" fill-rule="evenodd">
#                </path>
#               </svg>
#              </span>
#              <span class="sc-jKJlTe bVgqOb">
#               Menu
#              </span>
#             </button>
#             <a class="ds-primary-link sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https://olx.com.br">
#              <span class="sc-jKJlTe bVgqOb">
#               Página inicial
#              </span>
#              <span aria-hidden="true" class="sc-jGxEUC iYoIcd">
#               <svg class="default sc-cBdUnI bbFokt" data-ds-component="DS-LogoOLX" viewbox="0 0 40 40">
#                <g fill="none" fill-rule="evenodd">
#                 <path class="o" d="M7.579 26.294c-2.282 0-3.855-1.89-3.855-4.683 0-2.82 1.573-4.709 3.855-4.709 2.28 0 3.855 1.889 3.855 4.682 0 2.82-1.574 4.71-3.855 4.71m0 3.538c4.222 0 7.578-3.512 7.578-8.248 0-4.682-3.173-8.22-7.578-8.22C3.357 13.363 0 16.874 0 21.61c0 4.763 3.173 8.221 7.579 8.221">
#                 </path>
#                 <path class="l" d="M18.278 23.553h7.237c.499 0 .787-.292.787-.798V20.44c0-.505-.288-.798-.787-.798h-4.851V9.798c0-.505-.288-.798-.787-.798h-2.386c-.498 0-.787.293-.787.798v12.159c0 1.038.551 1.596 1.574 1.596">
#                 </path>
#                 <path class="x" d="M28.112 29.593l4.353-5.082 4.222 5.082c.367.452.839.452 1.258.08l1.705-1.517c.42-.373.472-.851.079-1.277l-4.694-5.321 4.274-4.869c.367-.426.34-.878-.078-1.277l-1.6-1.463c-.42-.4-.892-.373-1.259.08l-3.907 4.602-3.986-4.603c-.367-.425-.84-.479-1.259-.08l-1.652 1.49c-.42.4-.446.825-.053 1.278l4.354 4.868-4.747 5.348c-.393.452-.34.905.079 1.277l1.652 1.464c.42.372.891.345 1.259-.08">
#                 </path>
#                </g>
#               </svg>
#              </span>
#             </a>
#             <div class="sc-jdfcpN cQPuAI">
#              <div class="sc-1i3d8qn-0 esODqn">
#               <div class="undefined false sc-11ykbmp-0 ioAVKB">
#                <form class="sc-1i3d8qn-1 eWNSWv">
#                 <div class="search-wrap-box">
#                  <div class="sc-chPdSV gWxTLm" data-ds-component="DS-Autocomplete">
#                   <div class="combobox-wrapper">
#                    <div aria-busy="false" aria-controls="autocomplete-list" aria-expanded="false" aria-haspopup="listbox" aria-owns="autocomplete-list" class="" data-testid="searchtext-combobox" id="searchtext-combobox" role="combobox">
#                     <div class="sc-kgoBCf gPukpx sc-htoDjs hSiWqw" data-ds-component="DS-TextInput">
#                      <span class="sc-dnqmqq irpDAC">
#                       <input aria-autocomplete="list" aria-busy="false" aria-disabled="false" aria-errormessage="" aria-invalid="false" aria-label="Autocomplete" autocomplete="off" class="sc-iwsKbI kbHpBK" data-testid="searchtext-input" id="searchtext-input" label="" placeholder="Buscar" spellcheck="false" style="font-family:var(--font-family)" type="text" value=""/>
#                      </span>
#                     </div>
#                    </div>
#                   </div>
#                  </div>
#                  <button class="search-button-submit">
#                   <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                    <path d="M16.84 15.78l4.69 4.69a.75.75 0 01-1.06 1.06l-4.69-4.69a8.25 8.25 0 111.06-1.06zm-1.51-.564a6.75 6.75 0 10-.113.113.759.759 0 01.112-.113z" fill="currentColor" fill-rule="evenodd">
#                    </path>
#                   </svg>
#                   <span class="sc-jKJlTe bVgqOb">
#                    Buscar
#                   </span>
#                  </button>
#                 </div>
#                </form>
#               </div>
#              </div>
#             </div>
#            </div>
#            <div class="loaded sc-jMMfwr hbByQ">
#             <ul class="desapegar sc-jdeSqf HAmtJ">
#              <li class="hide-on-tablet sc-cBrjTV bKUeFO">
#               <a class="header-link ds-primary-link sc-gzVnrw sIgOl" data-ds-component="DS-Link" href="https://planoprofissional.olx.com.br/">
#                <span aria-hidden="true" class="sc-iCwjlJ bDXZLe">
#                 <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M7.25 6.25V5A2.75 2.75 0 0110 2.25h4A2.75 2.75 0 0116.75 5v1.25H20A2.75 2.75 0 0122.75 9v10A2.75 2.75 0 0120 21.75H4A2.75 2.75 0 011.25 19V9A2.75 2.75 0 014 6.25h3.25zm1.5 0h6.5V5c0-.69-.56-1.25-1.25-1.25h-4c-.69 0-1.25.56-1.25 1.25v1.25zM4 7.75c-.69 0-1.25.56-1.25 1.25v10c0 .69.56 1.25 1.25 1.25h16c.69 0 1.25-.56 1.25-1.25V9c0-.69-.56-1.25-1.25-1.25H4z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </span>
#                <span class="sc-jUpvKA xycMU">
#                 Plano Profissional
#                </span>
#               </a>
#              </li>
#              <li class="hide-on-tablet sc-cBrjTV bKUeFO">
#               <a class="header-link ds-primary-link sc-gzVnrw sIgOl" data-ds-component="DS-Link" href="https://conta.olx.com.br/anuncios">
#                <span aria-hidden="true" class="sc-iCwjlJ bDXZLe">
#                 <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M3 2.25h7a.75.75 0 01.75.75v7a.75.75 0 01-.75.75H3a.75.75 0 01-.75-.75V3A.75.75 0 013 2.25zm.75 7h5.5v-5.5h-5.5v5.5zm10.25-7h7a.75.75 0 01.75.75v7a.75.75 0 01-.75.75h-7a.75.75 0 01-.75-.75V3a.75.75 0 01.75-.75zm.75 7h5.5v-5.5h-5.5v5.5zm-.75 4h7a.75.75 0 01.75.75v7a.75.75 0 01-.75.75h-7a.75.75 0 01-.75-.75v-7a.75.75 0 01.75-.75zm.75 7h5.5v-5.5h-5.5v5.5zM3 13.25h7a.75.75 0 01.75.75v7a.75.75 0 01-.75.75H3a.75.75 0 01-.75-.75v-7a.75.75 0 01.75-.75zm.75 7h5.5v-5.5h-5.5v5.5z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </span>
#                <span class="sc-jUpvKA xycMU">
#                 Meus Anúncios
#                </span>
#               </a>
#              </li>
#              <li class="sc-cBrjTV bKUeFO">
#               <a class="header-link ds-primary-link sc-gzVnrw sIgOl" data-ds-component="DS-Link" href="https://conta.olx.com.br/chats">
#                <span aria-hidden="true" class="sc-iCwjlJ bDXZLe">
#                 <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M20.77 15.635a9.25 9.25 0 01-8.268 5.115 9.13 9.13 0 01-3.854-.842l-5.41 1.804a.75.75 0 01-.95-.95l1.804-5.41A9.128 9.128 0 013.25 11.5a9.249 9.249 0 015.112-8.27 9.128 9.128 0 014.138-.98l.541.001c4.698.26 8.449 4.01 8.709 8.749v.5a9.127 9.127 0 01-.98 4.135zM8.464 18.39a.75.75 0 01.575.042 7.632 7.632 0 003.462.819 7.751 7.751 0 006.93-4.288 7.63 7.63 0 00.82-3.46l.001-.46C20.034 7.106 16.893 3.965 13 3.75h-.502a7.634 7.634 0 00-3.463.82 7.75 7.75 0 00-4.285 6.932 7.63 7.63 0 00.82 3.46.75.75 0 01.042.575l-1.426 4.277 4.277-1.425z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                </span>
#                <span class="show-on-tablet sc-jUpvKA xycMU">
#                 Chat
#                </span>
#               </a>
#              </li>
#              <li class="sc-cBrjTV bKUeFO">
#               <a class="header-link ds-primary-link sc-gzVnrw sIgOl" data-ds-component="DS-Link" href="https://conta.olx.com.br/notificacoes">
#                <span aria-hidden="true" class="sc-iCwjlJ bDXZLe">
#                 <span class="sc-fkyLDJ NDYz" data-counter="0">
#                  <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                   <path d="M22 17.75H2c-1 0-1-1.5 0-1.5A2.25 2.25 0 004.25 14V9a7.75 7.75 0 0115.5 0v5A2.25 2.25 0 0022 16.25c1 0 1 1.5 0 1.5zM18.25 14V9a6.25 6.25 0 00-12.5 0v5c0 .844-.279 1.623-.75 2.25h14a3.733 3.733 0 01-.75-2.25zm-3.871 7.376a2.75 2.75 0 01-4.758 0 .75.75 0 01.649-1.126h3.46a.75.75 0 01.649 1.126z" fill="currentColor" fill-rule="evenodd">
#                   </path>
#                  </svg>
#                 </span>
#                </span>
#                <span class="show-on-tablet sc-jUpvKA xycMU">
#                 Notificações
#                </span>
#               </a>
#              </li>
#              <li class="sc-cBrjTV bKUeFO">
#               <div aria-busy="true" class="profile-skeleton sc-exkUMo dLqWjV" data-ds-component="DS-Skeleton" height="40px" width="135px">
#               </div>
#              </li>
#              <li class="sc-cBrjTV bKUeFO">
#               <a class="link-ad-button ds-primary-link sc-uJMKN dhyYGc" data-ds-component="DS-Button" data-testid="button-wrapper" href="https://www2.olx.com.br/desapega">
#                <div class="sc-jqCOkK ebdYDV">
#                 <span class="sc-jbKcbu cXqIMF" data-testid="icon-button">
#                  <svg aria-hidden="true" color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                   <path d="M12.75 11.25H19a.75.75 0 110 1.5h-6.25V19a.75.75 0 11-1.5 0v-6.25H5a.75.75 0 110-1.5h6.25V5a.75.75 0 111.5 0v6.25z" fill="currentColor" fill-rule="evenodd">
#                   </path>
#                  </svg>
#                 </span>
#                 <!-- -->
#                 Desapegar
#                </div>
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#           <div class="sc-jRuhRL jrbFUN">
#            <div class="sc-1i3d8qn-0 esODqn">
#             <div class="undefined false sc-11ykbmp-0 ioAVKB">
#              <form class="sc-1i3d8qn-1 eWNSWv">
#               <div class="search-wrap-box">
#                <div class="sc-chPdSV gWxTLm" data-ds-component="DS-Autocomplete">
#                 <div class="combobox-wrapper">
#                  <div aria-busy="false" aria-controls="autocomplete-list" aria-expanded="false" aria-haspopup="listbox" aria-owns="autocomplete-list" class="" data-testid="searchtext-combobox" id="searchtext-combobox" role="combobox">
#                   <div class="sc-kgoBCf gPukpx sc-htoDjs hSiWqw" data-ds-component="DS-TextInput">
#                    <span class="sc-dnqmqq irpDAC">
#                     <input aria-autocomplete="list" aria-busy="false" aria-disabled="false" aria-errormessage="" aria-invalid="false" aria-label="Autocomplete" autocomplete="off" class="sc-iwsKbI kbHpBK" data-testid="searchtext-input" id="searchtext-input" label="" placeholder="Buscar" spellcheck="false" style="font-family:var(--font-family)" type="text" value=""/>
#                    </span>
#                   </div>
#                  </div>
#                 </div>
#                </div>
#                <button class="search-button-submit">
#                 <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#                  <path d="M16.84 15.78l4.69 4.69a.75.75 0 01-1.06 1.06l-4.69-4.69a8.25 8.25 0 111.06-1.06zm-1.51-.564a6.75 6.75 0 10-.113.113.759.759 0 01.112-.113z" fill="currentColor" fill-rule="evenodd">
#                  </path>
#                 </svg>
#                 <span class="sc-jKJlTe bVgqOb">
#                  Buscar
#                 </span>
#                </button>
#               </div>
#              </form>
#             </div>
#            </div>
#           </div>
#          </nav>
#         </header>
#        </div>
#       </div>
#      </div>
#      <div class="h3us20-6 kUhqjE">
#       <div class="h3us20-4 cxGeqJ" from="lg">
#        <div>
#         <div class="sticky-outer-wrapper z9bd5q-0 dkdVuH">
#          <div class="sticky-inner-wrapper" style="position:relative;top:0px;z-index:5">
#           <div class="sc-EHOje sc-1kpmm0z-0 eWSASP" data-ds-component="DS-Flex" data-testid="filtersTab">
#            <div class="sc-EHOje sc-1kpmm0z-1 kAjtPt" data-ds-component="DS-Flex">
#             <button class="sc-1kpmm0z-2 bhIzcq sc-uJMKN lfTqxY" data-ds-component="DS-Button" data-testid="button-wrapper">
#              <div class="sc-jqCOkK ebdYDV">
#               <span class="sc-1kpmm0z-3 eFFEHx sc-ifAKCX jViSDP" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#                João Pessoa
#               </span>
#              </div>
#             </button>
#            </div>
#            <div class="sc-EHOje sc-1kpmm0z-4 iMTZxE" data-ds-component="DS-Flex">
#            </div>
#            <div class="sc-EHOje sc-1kpmm0z-1 kAjtPt" data-ds-component="DS-Flex">
#             <div class="sc-1kpmm0z-7 esYoDB">
#              <label class="sc-1kpmm0z-5 kqkkpF" for="hidden-select">
#               <span class="sc-1kpmm0z-3 eFFEHx sc-ifAKCX jViSDP" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#                Aluguel - casas e apartamentos
#               </span>
#              </label>
#              <select class="sc-1kpmm0z-6 kbFAIO" id="hidden-select">
#               <option value="all">
#                Todas as Categorias
#               </option>
#               <option value="1000">
#                -- Imóveis --
#               </option>
#               <option value="1001">
#                Venda - casas e apartamentos
#               </option>
#               <option selected="" value="1002">
#                Aluguel - casas e apartamentos
#               </option>
#               <option value="1080">
#                Temporada
#               </option>
#               <option value="1100">
#                Terrenos, sítios e fazendas
#               </option>
#               <option value="1120">
#                Comércio e indústria
#               </option>
#               <option value="1140">
#                Lançamentos
#               </option>
#               <option value="2000">
#                -- Autos e peças --
#               </option>
#               <option value="2020">
#                Carros, vans e utilitários
#               </option>
#               <option value="2040">
#                Caminhões
#               </option>
#               <option value="2050">
#                Ônibus
#               </option>
#               <option value="2060">
#                Motos
#               </option>
#               <option value="2080">
#                Barcos e aeronaves
#               </option>
#               <option value="2100">
#                Peças e acessórios
#               </option>
#               <option value="2101">
#                Peças para carros, vans e utilitários
#               </option>
#               <option value="2102">
#                Peças para caminhões
#               </option>
#               <option value="2103">
#                Peças para motos
#               </option>
#               <option value="2104">
#                Peças para barcos e aeronaves
#               </option>
#               <option value="2105">
#                Peças para ônibus
#               </option>
#               <option value="3000">
#                -- Eletrônicos e celulares --
#               </option>
#               <option value="3020">
#                Videogames
#               </option>
#               <option value="3040">
#                Computadores e acessórios
#               </option>
#               <option value="3060">
#                Celulares e telefonia
#               </option>
#               <option value="3080">
#                Áudio, TV, vídeo e fotografia
#               </option>
#               <option value="5000">
#                -- Para a sua casa --
#               </option>
#               <option value="5020">
#                Móveis
#               </option>
#               <option value="5040">
#                Eletrodomésticos
#               </option>
#               <option value="5060">
#                Materiais de construção e jardim
#               </option>
#               <option value="5080">
#                Utilidades domésticas
#               </option>
#               <option value="5100">
#                Objetos de decoração
#               </option>
#               <option value="5120">
#                Eletroportáteis
#               </option>
#               <option value="6000">
#                -- Esportes e lazer --
#               </option>
#               <option value="6020">
#                Esportes e ginástica
#               </option>
#               <option value="6060">
#                Ciclismo
#               </option>
#               <option value="7000">
#                -- Serviços --
#               </option>
#               <option value="7020">
#                Vagas de emprego
#               </option>
#               <option value="7060">
#                Serviços
#               </option>
#               <option value="7080">
#                Outros itens para comércio e escritório
#               </option>
#               <option value="8000">
#                -- Moda e beleza --
#               </option>
#               <option value="8020">
#                Beleza e saúde
#               </option>
#               <option value="8040">
#                Roupas e calçados
#               </option>
#               <option value="8060">
#                Bolsas, malas e mochilas
#               </option>
#               <option value="8080">
#                Bijouterias, relógios e acessórios
#               </option>
#               <option value="9000">
#                -- Artigos infantis --
#               </option>
#               <option value="9020">
#                Artigos infantis
#               </option>
#               <option value="10000">
# ...
#         </div>
#         <div class="sc-EHOje cxdaxN" data-ds-component="DS-Flex">
#          <div class="sc-EHOje chp44w-0 eKXhEQ" data-ds-component="DS-Flex">
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/agro-e-industria">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Agro e indústria
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/animais-de-estimacao">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Animais de estimação
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/artigos-infantis">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Artigos infantis
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/autos-e-pecas">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Autos e peças
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/comercio-e-escritorio">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Comércio e escritório
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/eletronicos-e-celulares">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Eletrônicos e celulares
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/esportes-e-lazer">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Esportes e lazer
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/imoveis">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Imóveis
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/moda-e-beleza">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Moda e beleza
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/musica-e-hobbies">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Música e hobbies
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/para-a-sua-casa">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Para a sua casa
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/servicos">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Serviços
#             </span>
#            </a>
#           </div>
#           <div class="sc-EHOje chp44w-1 dhRfTv" data-ds-component="DS-Flex">
#            <a class="sc-gzVnrw KJfcY" data-ds-component="DS-Link" href="https: //www.olx.com.br/vagas-de-emprego">
#             <span class="chp44w-4 htvnvL sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#              Vagas de emprego
#             </span>
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <footer class="sc-jDwBTQ dWtMUn" data-ds-component="DS-Footer" id="footer" style="margin:auto">
#       <hr class="sc-jAaTju effUCd" data-ds-component="DS-Divider"/>
#       <div class="sc-gPEVay gPZcyB">
#        <div class="sc-iRbamj cmOmwy">
#         <nav aria-label="Links comuns" class="sc-gipzik dQjJRh">
#          <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.olx.com.br/faq.htm">
#           <span class="sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#            Ajuda e contato
#           </span>
#          </a>
#          <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.olx.com.br/seguranca">
#           <span class="sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#            Dicas de segurança
#           </span>
#          </a>
#          <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.olx.com.br/vender">
#           <span class="sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#            Vender na OLX
#           </span>
#          </a>
#          <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.olx.com.br/planos">
#           <span class="sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#            Plano Profissional
#           </span>
#          </a>
#          <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.olx.com.br/mapa-do-site">
#           <span class="sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#            Mapa do site
#           </span>
#          </a>
#         </nav>
#         <nav aria-label="Mídias sociais" class="sc-csuQGl bFIsKI">
#          <a aria-label="Facebook" class="sc-jhAzac sc-fBuWsC eIvdxS sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.facebook.com/olxbrasil">
#           <span aria-hidden="true" class="sc-hzDkRC dfJNkV">
#            <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M9.216 22.91V12.452H7V8.85h2.216V6.688C9.216 3.748 10.466 2 14.02 2h2.959v3.604h-1.85c-1.383 0-1.475.504-1.475 1.443L13.65 8.85H17l-.392 3.603h-2.959V22.91H9.216z" fill="currentColor" fill-rule="evenodd">
#             </path>
#            </svg>
#           </span>
#           <span class="sc-jKJlTe bVgqOb">
#            Facebook
#           </span>
#          </a>
#          <a aria-label="YouTube" class="sc-jhAzac sc-fMiknA clMRaN sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.youtube.com/user/OLXBrasil">
#           <span aria-hidden="true" class="sc-hzDkRC dfJNkV">
#            <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M21.182 15.604c0 3.123-3.133 3.123-3.133 3.123H6.132C3 18.727 3 15.604 3 15.604v-6.48C3 6 6.132 6 6.132 6H18.05c3.133 0 3.133 3.123 3.133 3.123v6.48zm-5.561-3.231L9.669 8.887v6.97l5.952-3.484z" fill="currentColor" fill-rule="evenodd">
#             </path>
#            </svg>
#           </span>
#           <span class="sc-jKJlTe bVgqOb">
#            Youtube
#           </span>
#          </a>
#          <a aria-label="LinkedIn" class="sc-jhAzac sc-dVhcbM cassMN sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.linkedin.com/company/olx-brasil">
#           <span aria-hidden="true" class="sc-hzDkRC dfJNkV">
#            <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M3.459 8.83h3.543v12.35H3.46V8.83zM5.14 7.285h-.025C3.832 7.285 3 6.341 3 5.145 3 3.926 3.856 3 5.165 3c1.307 0 2.111.923 2.137 2.142 0 1.196-.83 2.143-2.162 2.143zm16.042 13.897h-4.019v-6.393c0-1.672-.628-2.813-2.01-2.813-1.058 0-1.646.77-1.92 1.513-.102.265-.086.637-.086 1.01v6.683h-3.98s.05-11.323 0-12.352h3.98v1.938c.235-.847 1.507-2.057 3.537-2.057 2.52 0 4.498 1.778 4.498 5.602v6.869z" fill="currentColor" fill-rule="evenodd">
#             </path>
#            </svg>
#           </span>
#           <span class="sc-jKJlTe bVgqOb">
#            LinkedIn
#           </span>
#          </a>
#          <a aria-label="Instagram" class="sc-jhAzac sc-eqIVtm kcKPUk sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://instagram.com/olxbr">
#           <span aria-hidden="true" class="sc-hzDkRC dfJNkV">
#            <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M12 2c2.716 0 3.056.012 4.123.06 1.064.049 1.791.218 2.427.465a4.902 4.902 0 011.772 1.153 4.902 4.902 0 011.153 1.772c.247.636.416 1.363.465 2.427.048 1.067.06 1.407.06 4.123s-.012 3.056-.06 4.123c-.049 1.064-.218 1.791-.465 2.427a4.902 4.902 0 01-1.153 1.772 4.902 4.902 0 01-1.772 1.153c-.636.247-1.363.416-2.427.465-1.067.049-1.407.06-4.123.06s-3.056-.011-4.123-.06c-1.064-.049-1.791-.218-2.427-.465a4.902 4.902 0 01-1.772-1.153 4.902 4.902 0 01-1.153-1.772c-.247-.636-.416-1.363-.465-2.427C2.011 15.056 2 14.716 2 12s.011-3.056.06-4.123c.049-1.064.218-1.791.465-2.427a4.902 4.902 0 011.153-1.772A4.902 4.902 0 015.45 2.525c.636-.247 1.363-.416 2.427-.465C8.944 2.012 9.284 2 12 2zm0 1.802c-2.67 0-2.986.01-4.04.058-.976.045-1.505.208-1.858.344-.466.182-.8.399-1.15.748-.35.35-.566.684-.748 1.15-.137.353-.3.882-.344 1.857-.048 1.055-.058 1.37-.058 4.041 0 2.67.01 2.986.058 4.04.045.976.207 1.505.344 1.858.182.466.399.8.748 1.15.35.35.684.566 1.15.748.353.137.882.3 1.857.344 1.054.048 1.37.058 4.041.058 2.67 0 2.987-.01 4.04-.058.976-.045 1.505-.207 1.858-.344.466-.182.8-.399 1.15-.748.35-.35.566-.684.748-1.15.136-.353.3-.882.344-1.857.048-1.055.058-1.37.058-4.041 0-2.67-.01-2.986-.058-4.04-.045-.976-.208-1.505-.344-1.858a3.098 3.098 0 00-.748-1.15 3.099 3.099 0 00-1.15-.748c-.353-.136-.882-.3-1.857-.344-1.055-.048-1.37-.058-4.041-.058zm.02 3.079a5.139 5.139 0 110 10.278 5.139 5.139 0 010-10.278zm0 8.475a3.336 3.336 0 100-6.672 3.336 3.336 0 000 6.672zm6.488-8.713a1.19 1.19 0 11-2.381 0 1.19 1.19 0 012.38 0z" fill="currentColor" fill-rule="evenodd">
#             </path>
#            </svg>
#           </span>
#           <span class="sc-jKJlTe bVgqOb">
#            Instagram
#           </span>
#          </a>
#          <a aria-label="Twitter" class="sc-jhAzac sc-fAjcbJ dEjXeK sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://twitter.com/olx_Brasil">
#           <span aria-hidden="true" class="sc-hzDkRC dfJNkV">
#            <svg color="currentColor" height="24" size="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
#             <path d="M18.842 6.587a4.1 4.1 0 001.721-2.284 7.596 7.596 0 01-2.488 1.002A3.813 3.813 0 0015.217 4c-2.163 0-3.915 1.85-3.915 4.13 0 .324.032.64.1.941-3.255-.172-6.14-1.815-8.073-4.316a4.294 4.294 0 00-.53 2.078c0 1.432.691 2.697 1.742 3.439a3.777 3.777 0 01-1.775-.516v.05c0 2.002 1.35 3.672 3.144 4.05-.33.097-.675.146-1.034.146-.252 0-.498-.025-.736-.073.498 1.64 1.944 2.836 3.659 2.868A7.604 7.604 0 012 18.508a10.68 10.68 0 006.004 1.856c7.205 0 11.143-6.295 11.143-11.754 0-.18-.002-.358-.01-.534a8.187 8.187 0 001.954-2.139 7.507 7.507 0 01-2.249.65z" fill="currentColor" fill-rule="evenodd">
#             </path>
#            </svg>
#           </span>
#           <span class="sc-jKJlTe bVgqOb">
#            Twitter
#           </span>
#          </a>
#         </nav>
#        </div>
#        <hr class="sc-jAaTju effUCd" data-ds-component="DS-Divider"/>
#        <div class="sc-jlyJG ifavhK">
#         <nav aria-label="Links Jurídicos" class="sc-Rmtcm JwzRF">
#          <span class="sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#           <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://portal.olx.com.br/">
#            Sobre a OLX
#           </a>
#           ,
#           <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://www.olx.com.br/copyright.htm">
#            Termos de uso
#           </a>
#           ,
#           <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://ajuda.olx.com.br/s/article/politica-de-privacidade">
#            Política de privacidade
#           </a>
#           , e
#           <!-- -->
#           <a class="sc-gzVnrw eNmqhV" data-ds-component="DS-Link" href="https://ajuda.olx.com.br/s/article/protecao-a-propriedade">
#            Proteção à Propriedade Intelectual
#           </a>
#          </span>
#         </nav>
#         <address class="sc-bRBYWo pRgjx">
#          <span class="sc-ifAKCX lgjPoE" color="--color-neutral-130" data-ds-component="DS-Text" display="block">
#           © Bom Negócio Atividades de Internet Ltda. Rua do Catete, 359, Flamengo - 22220-001 - Rio de Janeiro, RJ
#          </span>
#         </address>
#        </div>
#       </div>
#      </footer>
#     </div>
#    </div>
#   </div>
#   <script async="" defer="" src="https://static.olx.com.br/cd/vi/js/listing-v3/b66c1ebd97decf73d139.bundle_vendors.js">
#   </script>
#   <script async="" defer="" src="https://static.olx.com.br/cd/vi/js/listing-v3/943897f8fdac1671f261.bundle_olxcommon.js">
#   </script>
#   <script async="" defer="" src="https://static.olx.com.br/cd/vi/js/listing-v3/d7a8c7113f91ac4fe4e1.bundle_listingDesk.js">
#   </script>
#   <script async="" defer="" src="https://static.olx.com.br/cd/listing-web/ScrollBanner.js">
#   </script>
#   <script defer="">
#    (function(h,o,t,j,a,r){ h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)}; h._hjSettings={hjid:736533,hjsv:6}; a=o.getElementsByTagName('head')[0]; r=o.createElement('script');r.async=1; r.src=t+h._hjSettings.hjid+j+h._hjSettings.hjsv; a.appendChild(r); })(window,document,'https://static.hotjar.com/c/hotjar-','.js?sv=');
#   </script>
#   <script defer="">
#    var _comscore = _comscore || []; _comscore.push({ c1: "2", c2: "29823456" }); (function() { var s = document.createElement("script"), el = document.getElementsByTagName("script")[0]; s.async = true; s.src = (document.location.protocol == "https:" ? "https://sb" : "http://b") + ".scorecardresearch.com/beacon.js"; el.parentNode.insertBefore(s, el); })();
#   </script>
#   <noscript>
#    <img src="https://sb.scorecardresearch.com/p?c1=2&amp;c2=29823456&amp;cv=2.0&amp;cj=1"/>
#   </noscript>
#   <script defer="" src="https://cdnjs.cloudflare.com/ajax/libs/fingerprintjs2/2.1.0/fingerprint2.min.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://static.olx.com.br/olx/js/lurker.min.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
soup.title
# Out:
# <title>Casas e apartamentos para alugar - João Pessoa, Paraíba | OLX</title>
